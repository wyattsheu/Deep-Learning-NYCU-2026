# %%
# 1. 從你的 GitHub 複製專案
# %cd /content
# !git clone https://github.com/wyattsheu/Deep-Learning-NYCU-2026.git

# 2. 切換工作目錄到 Lab2
# %cd Deep-Learning-NYCU-2026/Lab2

# 檢查一下是不是成功進來了 (應該要看到 src, requirements.txt 等檔案)
# !ls
# Out:
# Cloning into 'Deep-Learning-NYCU-2026'...
# remote: Enumerating objects: 34, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (29/29), done.
# ^Cceiving objects:  35% (12/34), 1.92 MiB | 1.25 MiB/s
# [Errno 2] No such file or directory: 'Deep-Learning-NYCU-2026/Lab2'
# /content/Deep-Learning-NYCU-2026/Lab2
# colab_run.ipynb  Lab2_Binary_Semantic_Segmentation_2026_Spring.pdf  src
# dataset		 requirements.txt

# %%
# 1. 建立存放資料的目錄
# !mkdir -p dataset/oxford-iiit-pet

# 2. 下載圖片檔與標註檔 (-P 代表指定下載路徑)
# !wget -P dataset/oxford-iiit-pet https://thor.robots.ox.ac.uk/~vgg/data/pets/images.tar.gz
# !wget -P dataset/oxford-iiit-pet https://thor.robots.ox.ac.uk/~vgg/data/pets/annotations.tar.gz

# 3. 解壓縮檔案到指定目錄
# !tar -xf dataset/oxford-iiit-pet/images.tar.gz -C data/oxford-iiit-pet/
# !tar -xf dataset/oxford-iiit-pet/annotations.tar.gz -C data/oxford-iiit-pet/

# 4. 刪除壓縮檔以節省 Colab 空間
# !rm dataset/oxford-iiit-pet/*.tar.gz

print("資料集下載與解壓縮完成！")
# Out:
# --2026-03-19 03:06:36--  https://thor.robots.ox.ac.uk/~vgg/data/pets/images.tar.gz
# Resolving thor.robots.ox.ac.uk (thor.robots.ox.ac.uk)... 129.67.95.98
# Connecting to thor.robots.ox.ac.uk (thor.robots.ox.ac.uk)|129.67.95.98|:443... connected.
# HTTP request sent, awaiting response... 308 Permanent Redirect
# Location: https://thor.robots.ox.ac.uk/pets/images.tar.gz [following]
# --2026-03-19 03:06:36--  https://thor.robots.ox.ac.uk/pets/images.tar.gz
# Reusing existing connection to thor.robots.ox.ac.uk:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 791918971 (755M) [application/octet-stream]
# Saving to: ‘dataset/oxford-iiit-pet/images.tar.gz’
#
# images.tar.gz       100%[===================>] 755.23M  24.1MB/s    in 32s
#
# 2026-03-19 03:07:08 (23.7 MB/s) - ‘dataset/oxford-iiit-pet/images.tar.gz’ saved [791918971/791918971]
#
# --2026-03-19 03:07:09--  https://thor.robots.ox.ac.uk/~vgg/data/pets/annotations.tar.gz
# ...

# %%
# 根據你的 requirements.txt 安裝套件
# !pip install -r requirements.txt

# %%
# !git branch -r
# Out:
#   origin/HEAD -> origin/main
#   origin/main

# %%
# 1. 確保同步遠端最新狀態
# !git fetch origin

# 2. 強制將本地分支重設為遠端的 main 分支
# !git reset --hard origin/main
# Out:
# HEAD is now at 3ff27a2 Initial commit: Add Lab0, Lab1, and Lab2 (U-Net Semantic Segmentation)

# %%
# 執行你的訓練主程式
# !python3 src./train.py
# Out:
# Traceback (most recent call last):
#   File "/content/Deep-Learning-NYCU-2026/Lab2/src/train.py", line 92, in <module>
#     train()
#   File "/content/Deep-Learning-NYCU-2026/Lab2/src/train.py", line 31, in train
#     train_dataset = OxfordPetDataset(data_dir, split_type="train")
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Deep-Learning-NYCU-2026/Lab2/src/oxford_pet.py", line 14, in __init__
#     with open(os.path.join(data_dir, f"{split_type}.txt"), "r") as f:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'dataset/oxford-iiit-pet/train.txt'

# %%
# !ls
# Out:
# colab_run.ipynb  Lab2_Binary_Semantic_Segmentation_2026_Spring.pdf  src
# dataset		 requirements.txt
